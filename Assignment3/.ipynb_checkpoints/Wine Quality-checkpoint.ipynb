# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn import metrics
import seaborn as sns
import matplotlib.cm as cm

# %% [markdown]
# # K-means on wine quality dataset

# %%
data = pd.read_csv("data/winequality.csv")
print(data.shape)
X = data.iloc[:,:11]
y = data.iloc[:,11]
def normalize(dataset):
    dataNorm=((dataset-dataset.min())/(dataset.max()-dataset.min()))*20
    return dataNorm
X = normalize(X)
ax = sns.distplot(data['quality'])
plt.show()
# Out:
# (3918, 13)

# %%
# Out:
# 0.011404229445
# 0.0452244811305
# 0.0240902852575
# 0.0339929365909

# %% [markdown]
# ## How to evalute the clustering algorithm performance?
# Evaluating the performance of a clustering algorithm is not as trivial as counting the number of errors or the precision and recall of a supervised classification algorithm. In particular any evaluation metric should not take the absolute values of the cluster labels into account but rather if this clustering define separations of the data similar to some ground truth set of classes or satisfying some assumption such that members belong to the same class are more similar that members of different classes according to some similarity metric.
#
# https://scikit-learn.org/stable/modules/clustering.html#clustering-performance-evaluation
# https://stats.stackexchange.com/questions/79028/performance-metrics-to-evaluate-unsupervised-learning

# %%
for num in range(3,11):
    print("---------------k = ",num," ------------")
    kmeans = KMeans(n_clusters=num) 
    kmeans.fit(X)
    print("Adjusted Rand index: ",metrics.adjusted_rand_score(np.array(y), kmeans.labels_))
    print("Homogeneity: ",metrics.homogeneity_score(np.array(y), kmeans.labels_))
    print("completeness: ",metrics.completeness_score(np.array(y), kmeans.labels_))
    print("V-measure: ",metrics.v_measure_score(np.array(y), kmeans.labels_))
    print("Mutual Information: ",metrics.adjusted_mutual_info_score(np.array(y), kmeans.labels_))
    print("Silhouette Coefficient: ",metrics.silhouette_score(X,kmeans.labels_, metric='euclidean'))
# Out:
# ---------------k =  3  ------------
# Adjusted Rand index:  0.0700531448234
# Homogeneity:  0.0758748383983
# completeness:  0.091010874946
# V-measure:  0.0827564599825
# Mutual Information:  0.0747291937355
# Silhouette Coefficient:  0.193379763038
# ---------------k =  4  ------------
# Adjusted Rand index:  0.0660599908954
# Homogeneity:  0.0871857503237
# completeness:  0.0830591454322
# V-measure:  0.0850724350189
# Mutual Information:  0.081425388616
# Silhouette Coefficient:  0.17326129618
# ---------------k =  5  ------------
# Adjusted Rand index:  0.0589535743116
# Homogeneity:  0.0878458181336
# completeness:  0.0734752247347
# V-measure:  0.0800204500865
# Mutual Information:  0.0715439690157
# Silhouette Coefficient:  0.16803385893
# ---------------k =  6  ------------
# Adjusted Rand index:  0.0449683107668
# Homogeneity:  0.0950294114798
# completeness:  0.069910137072
# V-measure:  0.080557019111
# Mutual Information:  0.067777373789
# Silhouette Coefficient:  0.145164748051
# ---------------k =  7  ------------
# Adjusted Rand index:  0.0448047210308
# Homogeneity:  0.100805301026
# completeness:  0.0691021454165
# V-measure:  0.0819959656401
# Mutual Information:  0.0667248542532
# Silhouette Coefficient:  0.144632158155
# ---------------k =  8  ------------
# Adjusted Rand index:  0.039674573977
# Homogeneity:  0.112569628169
# completeness:  0.0718285325527
# V-measure:  0.0876983931915
# Mutual Information:  0.0692586002132
# Silhouette Coefficient:  0.142816935557
# ---------------k =  9  ------------
# Adjusted Rand index:  0.0376968003428
# Homogeneity:  0.119112456686
# completeness:  0.0714717347665
# V-measure:  0.0893376711548
# Mutual Information:  0.0687140972749
# Silhouette Coefficient:  0.131653792131
# ---------------k =  10  ------------
# Adjusted Rand index:  0.0377734037277
# Homogeneity:  0.118726357447
# completeness:  0.0703187667683
# V-measure:  0.0883248491408
# Mutual Information:  0.0672966058019
# Silhouette Coefficient:  0.138316364991

# %%
kmeans = KMeans(n_clusters=8) 
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=8, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %% [markdown]
# **To visualize, I project the points to 2-D space, I tried every combination of 2-D axises to find the best visualization**
# **All the figures are in figures/wine/ folder**

# %%
print(set(kmeans.labels_))
# Out:
# {0, 1, 2, 3, 4, 5, 6, 7}

# %%
def visialize_clustering(kmeans,num):
    LABEL_COLOR_MAP = {0 : 'k',
                   1 : 'red',
                   2 : 'tan',
                   3 : 'green',
                   4 : 'navy',
                   5 : 'plum',
                   6 : 'yellow',
                   7 : 'lightgrey',
                   }
    label_color = [LABEL_COLOR_MAP[l] for l in kmeans.labels_]
    for i in range(10):
        for j in range(i,11):
            centers = kmeans.cluster_centers_
            plt.scatter( X.iloc[:, i], X.iloc[:, j],c = label_color,s = 1)
            plt.scatter(centers[:, i], centers[:, j], s=50,c='black');
       
            plt.xlabel(list(X.columns.values)[i])
            plt.ylabel(list(X.columns.values)[j])
            plt.title("Wine: plot on projected space, # of cluster = ",num)
            plt.savefig("./figures/wine/%s_wine_%s_%s.jpg"%(num,i,j))
            plt.show()

# %%
# Out:
# (10, 11)
